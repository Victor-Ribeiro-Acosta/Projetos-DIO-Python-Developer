# %% [markdown]
# O flask cira um servidor de execução local do tipo localhost. O flask-ngrok é um framework que permite expor o servidor para tráfego externo ou funcionar fora do tempo de execução, com um protocolo http.

# %%
# !pip install flask_ngrok
# !pip install pyngrok
# !ngrok authtoken 2M1XqtFEmLxU8b7NBJNcDQ19nv1_52VdQ1yrUkUk4q4F75SGw

# %% [markdown]
# Iniciando flask e criando a primeira página

# %%
from flask import *
from flask_ngrok import run_with_ngrok
from pyngrok import ngrok

app = Flask(__name__)
run_with_ngrok(app)

url = ngrok.connect("5000")

@app.route("/")
def home():
  return '<p>Olá mundo!</p>'

app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
#  * Running on http://5d7c-35-224-202-59.ngrok-free.app
#  * Traffic stats available on http://127.0.0.1:4040
# INFO:werkzeug:127.0.0.1 - - [19/Jan/2024 20:03:06] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Jan/2024 20:03:06] "GET /favicon.ico HTTP/1.1" 404 -

# %%
# !pip install fastapi nest-asyncio pyngrok uvicorn
# !pip install uvicorn

# %%
from fastapi import FastAPI
import nest_asyncio
import uvicorn
from pyngrok import ngrok

app = FastAPI()
@app.get("/")

async def home():
  return 'Hello word!'

ngrok_tunnel = ngrok.connect(8000)
print(ngrok_tunnel.public_url)
nest_asyncio.apply()
uvicorn.run(app, port = 8000)
# Out:
# https://1569-35-224-202-59.ngrok-free.app
# INFO:     Started server process [2147]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     177.91.145.110:0 - "GET / HTTP/1.1" 200 OK
# INFO:     177.91.145.110:0 - "GET /favicon.ico HTTP/1.1" 404 Not Found
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [2147]

# %%
app.close()
